# %% [markdown]
# # Continued on new Jupyter Notebook

# %%
# We will see Tkinter

# %% [markdown]
# #### Tkinter

# %%
# This is a python module that provide access to widget tool kit that means it allows GUI programs to be created.

# %%
#lets test it out

import tkinter

print(tkinter.TkVersion)
print(tkinter.TclVersion)

tkinter._test()
# Out:
# 8.6
# 8.6

# %%
# Nice, it shows that we are working with version 8.6,
# If you have ran the above code, you would have got a new window stating the version of TkVersion and TclVersion
# And if you click the "Click Me" its puts a bracket around it, to show its working

# %%
# Now lets see create a new window

import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')
mainWindow.mainloop()

# %%
# Now if you would have ran the upper cell, you would have got a window, that has a title of "Hello World!"
# because of line 6 and the window has a size of 640x480 because of line 7

# %%
# One thing that is important in tkinter when you are defining a geometry, you have to pass the dimensions as a string.

# %%
# The geometry function have 4 components, the height, width, and the offset(top and left from the screen)
# The width and the height are separated by comma, but the offsets are separated by + and -

# lets see that in action

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480+8+400')
mainWindow.mainloop()

# %%
# So now the window is +8 pixels left of the screen and +400 pixels down from the top

# %%
# One thing to note here is that: 
# Everything in tk is a window and objects are placed in a hierarchy so in our example
# on the screen main window is the root window so everything else must be placed within it
# or within one of the child windows now not every window can have children but
# every window except the route one must have a master window

# %%
# lets see now how we can put widgets on the window,
# we are going to be working with a canvas widget(intened for displaying graphics) but we are gonna use
# it bcuz changing it we can have raised appreance and giving it a border, it is easier to see where
# it is on the screen. bcuz we are going to repositioning it.

# %%
import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='left')

mainWindow.mainloop()

# %%
# now if we want the canvas to fill the window from the left side, we can do so by

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='left', fill=tkinter.Y)

mainWindow.mainloop()

# %%
# But if you change the Y to X in line 11, you would think that it would fit the entire width of the screen
# if you do so, you would see it dosent actually work

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='left', fill=tkinter.X) #changing Y to X

mainWindow.mainloop()

# %%
# As you can see that dosent actually work

# %%
# To do so(fit the entire width of the screen in the window)
# we need to add another parameter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='left', fill=tkinter.X, expand=True)

mainWindow.mainloop()

# %%
# As you can see, it fills the entire width of the screen

# %%
# Now if we do it the other way expand it to the height, we will run into the same problem
# lets see, but first lets move the canvas to the top 

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='top', fill=tkinter.Y) #changed the position of canvas to the top

mainWindow.mainloop()

# %%
# But now if we want to fit it to height of the screen of the window, we again have to use the expan parameter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='top', fill=tkinter.Y, expand=True)

mainWindow.mainloop()

# %%
# Now if we want to expand it in both direction, we have to use .BOTH

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='top', fill=tkinter.BOTH) # used .BOTH here

mainWindow.mainloop()

# %%
# But as you can see it does expand horizontally but not vertically
# to do that we have to use the 'expand'

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top') # this will add a text at the top of the window.

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='top', fill=tkinter.BOTH, expand=True)

mainWindow.mainloop()

# %%
# lets now create buttons, to see how it effects the window.

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top')

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='left')

button1 = tkinter.Button(mainWindow, text="button1")
button2 = tkinter.Button(mainWindow, text="button2")
button3 = tkinter.Button(mainWindow, text="button3")

button1.pack(side='left')
button2.pack(side='left')
button3.pack(side='left')

mainWindow.mainloop()

# %%
# When widgets share the same side, they are placed adjacent to each other in order they're actually packed,
# but you can see the button are now in the center of the window, which is technically we don't want
# we can change this by changing the 'anchor' option which takes values corresponding to the four main of the compass

# %%
mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top')

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='left')

button1 = tkinter.Button(mainWindow, text="button1")
button2 = tkinter.Button(mainWindow, text="button2")
button3 = tkinter.Button(mainWindow, text="button3")

button1.pack(side='left',anchor='n')
button2.pack(side='left',anchor='s')
button3.pack(side='left',anchor='e')

mainWindow.mainloop()

# %%
# So you might think all three buttons are actually doing something here but
# what's probably not obviously its only n and s are actually doing anything here because the buttons have been
# packed to the vertical side of the window anchor can only be therefore affect vertical
# positioning horizontally the buttons place to the left of where the previous
# button ends similarly if we packed them to the top or bottom edges and anchors are only
# going to affect their horizontal position makes sense.

# %%
# Now seeing that, we will now change the canvas position to the top position and
# change the button position to top as well.

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top')

canvas = tkinter.Canvas(mainWindow, relief='raised', borderwidth=1)
canvas.pack(side='top')

button1 = tkinter.Button(mainWindow, text="button1")
button2 = tkinter.Button(mainWindow, text="button2")
button3 = tkinter.Button(mainWindow, text="button3")

button1.pack(side='top',anchor='n')
button2.pack(side='top',anchor='s')
button3.pack(side='top',anchor='e')

mainWindow.mainloop()

#doing this the anchor will now only effect the hiorizontal positiions

# %%
# So the documentation states that you can also specify the for intermediate compass points such as NW for
# north west for example but this will actually not make any difference to the behavior
# we've just observed widgets packed with vertical edge that's left or right
# can only have a vertical position altered by anchor the ones packed horizontal edge top
# and bottom can only have their horizontal positions change.

# %%
# Now although we can place widgets inside a frame to both group them
#together and position them a little bit better pack is really only suitable for very simple layouts

# %%
# Now the 3 geometry managers that are a part of tkinter, pack is the most basic one
# and the options are still bit too limited.

#But lets now add a Frame to our window

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.pack(side='top')

leftFrame = tkinter.Frame(mainWindow) #adding a left frame to the window
leftFrame.pack(side = 'left',anchor ='n',fill=tkinter.Y,expand=False)

canvas = tkinter.Canvas(leftFrame, relief='raised', borderwidth=1)
canvas.pack(side='left',anchor = 'n') #moving the canvas to the left and anchoring it to the north

rightFrame = tkinter.Frame(mainWindow) #moving the buttons to a right Frame 
rightFrame.pack(side='right',anchor='n',expand=True)
button1 = tkinter.Button(rightFrame, text="button1") #changing the mainWindow to rightFrame
button2 = tkinter.Button(rightFrame, text="button2")
button3 = tkinter.Button(rightFrame, text="button3")
#removing anchor from the buttons becuz it is already mentioned in the rightFrame
button1.pack(side='top')
button2.pack(side='top')
button3.pack(side='top')

mainWindow.mainloop()

# %%
# Now this is the result we were set out to achieve
# But pack is still limited to very basic layouts

# %%
# The next geometery manager, we will be looking at is 'place'. Its even simpler than pack.
# it works by specifying absolute positions for at least one window or indows that can be position relative
# to another window and unless you know the screen size of your program will
# be running on the use of absolute positioning is not recommended.

# %%
# Check out the video on 'Tkinter - Grid Geometery Manager' Udemy

# %%
# lets now simplfy the code using .grid

import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.grid(row=0, column=0) #changed to .grid

leftFrame = tkinter.Frame(mainWindow)
leftFrame.grid(row=1,column=1) #changed to .grid

canvas = tkinter.Canvas(leftFrame, relief='raised', borderwidth=1)
canvas.grid(row=1,column=0) #changed to .grid

rightFrame = tkinter.Frame(mainWindow)
rightFrame.grid(row=1,column=2)
button1 = tkinter.Button(rightFrame, text="button1")
button2 = tkinter.Button(rightFrame, text="button2")
button3 = tkinter.Button(rightFrame, text="button3")

button1.grid(row=0,column=0)
button2.grid(row=1,column=0)
button3.grid(row=2,column=0)

mainWindow.mainloop()

# %%
# You can see the buttons are sticking to the canvas, which we dont want, we can fix this by 'sticky' property

import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.grid(row=0, column=0)

leftFrame = tkinter.Frame(mainWindow)
leftFrame.grid(row=1,column=1)

canvas = tkinter.Canvas(leftFrame, relief='raised', borderwidth=1)
canvas.grid(row=1,column=0)

rightFrame = tkinter.Frame(mainWindow)
rightFrame.grid(row=1,column=2, sticky='n') #sticky uses anchor points to define
button1 = tkinter.Button(rightFrame, text="button1")
button2 = tkinter.Button(rightFrame, text="button2")
button3 = tkinter.Button(rightFrame, text="button3")

button1.grid(row=0,column=0)
button2.grid(row=1,column=0)
button3.grid(row=2,column=0)

mainWindow.mainloop()

# %%
# It fixes the issue but they are still to close to the frame,
# to fix that what we can do is we can configure the individual columns using the columns configure
# method to give weights to each column

import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.grid(row=0, column=0)

leftFrame = tkinter.Frame(mainWindow)
leftFrame.grid(row=1,column=1)

canvas = tkinter.Canvas(leftFrame, relief='raised', borderwidth=1)
canvas.grid(row=1,column=0)

rightFrame = tkinter.Frame(mainWindow)
rightFrame.grid(row=1,column=2, sticky='n')
button1 = tkinter.Button(rightFrame, text="button1")
button2 = tkinter.Button(rightFrame, text="button2")
button3 = tkinter.Button(rightFrame, text="button3")

button1.grid(row=0,column=0)
button2.grid(row=1,column=0)
button3.grid(row=2,column=0)


#configure the columns
mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(0,weight=1)
mainWindow.grid_columnconfigure(2, weight=1)

mainWindow.mainloop()

# %%
# It is now pretty similar to the pack solution we had.

# %% [markdown]
# ![Screenshot%20%2815%29.png](attachment:Screenshot%20%2815%29.png)

# %%
# So what we've done is we've created a grid containing two rows 0 and 1 and three columns 0 to 2.
# I just want to display that on the screen you can see the frame in row
# 1 column 2 is being split into three rows and what we've done is we've put
# orange lines to show the grids just you can sort of see what's happening with our code.

# %%
# Now we have a sticky parameter, that is used to change the position of the widget,
# and it uses compass directions to align the widget, the default is center.
# Now specifying 2 opposite points such as north and south will expand the widget to fill the cell in that direction
# setting all 4 directions will fill the cell completely.

# %%
# Now to see the change that will effect the frame, we will give it border and change its appreance.
# Also we are gonna use sticky in our code to expand the left frames so that's the full height
# of its rows and the right frame to be the full width of its column.

# %%
import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.grid(row=0, column=0)

leftFrame = tkinter.Frame(mainWindow)
leftFrame.grid(row=1,column=1)

canvas = tkinter.Canvas(leftFrame, relief='raised', borderwidth=1)
canvas.grid(row=1,column=0)

rightFrame = tkinter.Frame(mainWindow)
rightFrame.grid(row=1,column=2, sticky='n')
button1 = tkinter.Button(rightFrame, text="button1")
button2 = tkinter.Button(rightFrame, text="button2")
button3 = tkinter.Button(rightFrame, text="button3")

button1.grid(row=0,column=0)
button2.grid(row=1,column=0)
button3.grid(row=2,column=0)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(0,weight=1)
mainWindow.grid_columnconfigure(2, weight=1)

#changing the button's appreance
leftFrame.config(relief='sunken',borderwidth=1)
rightFrame.config(relief='sunken',borderwidth=1)
leftFrame.grid(sticky='ns')
rightFrame.grid(sticky='new')

mainWindow.mainloop()

# %%
# Notice the row height is now determined by the height of
# the tallest widget it contains the right hand frame in this case

# %%
# So what we should be able to do is make button2 the full width of its frame

import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.grid(row=0, column=0)

leftFrame = tkinter.Frame(mainWindow)
leftFrame.grid(row=1,column=1)

canvas = tkinter.Canvas(leftFrame, relief='raised', borderwidth=1)
canvas.grid(row=1,column=0)

rightFrame = tkinter.Frame(mainWindow)
rightFrame.grid(row=1,column=2, sticky='n')
button1 = tkinter.Button(rightFrame, text="button1")
button2 = tkinter.Button(rightFrame, text="button2")
button3 = tkinter.Button(rightFrame, text="button3")

button1.grid(row=0,column=0)
button2.grid(row=1,column=0)
button3.grid(row=2,column=0)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(0,weight=1)
mainWindow.grid_columnconfigure(2, weight=1)

#changing the button's appreance
leftFrame.config(relief='sunken',borderwidth=1)
rightFrame.config(relief='sunken',borderwidth=1)
leftFrame.grid(sticky='ns')
rightFrame.grid(sticky='new')

button2.grid(sticky='ew') # changing the position of button2

mainWindow.mainloop()

# %%
# If you run that you'll notice that it stil hasn't expanded, that where the weight parameter comes into play
# weight option is quite important to deciding the behaviour of widgets within cells
# so unless a weight has been set for a column or row them some options including sticky won't do anything.

# %%
import tkinter

mainWindow = tkinter.Tk()
mainWindow.title("Hello World!")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text ="Hello World!")
label.grid(row=0, column=0)

leftFrame = tkinter.Frame(mainWindow)
leftFrame.grid(row=1,column=1)

canvas = tkinter.Canvas(leftFrame, relief='raised', borderwidth=1)
canvas.grid(row=1,column=0)

rightFrame = tkinter.Frame(mainWindow)
rightFrame.grid(row=1,column=2, sticky='n')
button1 = tkinter.Button(rightFrame, text="button1")
button2 = tkinter.Button(rightFrame, text="button2")
button3 = tkinter.Button(rightFrame, text="button3")

button1.grid(row=0,column=0)
button2.grid(row=1,column=0)
button3.grid(row=2,column=0)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(0,weight=1)
mainWindow.grid_columnconfigure(2, weight=1)

#changing the button's appreance
leftFrame.config(relief='sunken',borderwidth=1)
rightFrame.config(relief='sunken',borderwidth=1)
leftFrame.grid(sticky='ns')
rightFrame.grid(sticky='new')

rightFrame.columnconfigure(0,weight=1)
button2.grid(sticky='ew') # changing the position of button2

mainWindow.mainloop()

# %%
# As you can see it works perfectly.

# %%
# But what we are doing is very basic, we are now going to build something like this

# %% [markdown]
# ![Screenshot%20%2816%29.png](attachment:Screenshot%20%2816%29.png)

# %%
# Now its a good idea that we need to divide the window into frames and then work our way up

# %% [markdown]
# ![Screenshot%20%2818%29.png](attachment:Screenshot%20%2818%29.png)

# %%
# Lets write the code for the window
# So first, we'll name the window "Grid Demo" and we can see "Tkinter Grid Demo" spans 3 columns, so lets implement that
import tkinter

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.mainloop()

# %%
# Now you will see, even though we mentioned that 'columnspan' is 3 and the default position is center,
# thats because we haven't specified the weights yet.

import tkinter

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)#as there are 5 columns

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

mainWindow.mainloop()

# %%
# now you can see the text is centred in the middle
# now lets make the list box and we see that the list box is spans 2 rows, so we will do that

import tkinter
import os #for our list

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)#as there are 5 columns

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2) #nsew because we wanna fill the entire 2 rows
fileList.config(border=2, relief='sunken') # there are more different reliefs, feel free to work them out yourself
for zone in os.listdir('/Windows/System32'): #we dont wanna manually enter a list, so we automated it
    fileList.insert(tkinter.END,zone) # tkinter.END is when you're inserting an item to a 
                                      # list box you need to specify the insertion point
                                      # So, we are using the Tkinter constant called END
                                      # and that places each entry at the end of the list as they are added

mainWindow.mainloop()

# %%
# perfect, now we need a scroll bar in the list box

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)
    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
# 'orient' basically orients the scrollbar, but command is new,
# command is how actions are associated with widgets and UI events,
# and it is set to yview, which is vertical view
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
# now there is one more step in linking the scroll box to list box and thats by using the 'yscrollcommand' option of the
# list box, and the list box call the set method of the scroll bar when it changes
# and the reason it might change, for example
# if more items are added to the list or items are scrolled using a keyboard or mouse
fileList['yscrollcommand'] = listScroll.set #for horizontal scrolling the command will be different

mainWindow.mainloop()

# %%
# Perfect, the list can be scrolled using mouse and keyboard

# %%
# Now lets work on the right side 'file details' widget

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)
    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#frame for the radio buttons
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") #labelframe it's very similar to frames,
                                                                 #but it allowsa caption to be sent using the text option
                                                                 #also the text option, creates a border
optionFrame.grid(row=1, column =2,sticky='ne')

rbValue = tkinter.IntVar() #this is because, at a time only one button can be selected, if one is selected
                           #the other one automatically deselects
rbValue.set(3) #here you can set, which radio button will selected before we run the code
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
#optionFrame because we are putting it inside a frame that inside the mainWindow
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
# now lets add a variable that we'll query, depending on the rbValue that we have clicked whether its 1,2 or 3.
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

mainWindow.mainloop()
# and out of intrest we will do this, this will print as a radio button is clicked
print(rbValue.get())
# Out:
# 3

# %%
# Perfect, the radio buttons are working perfectly and they are returning the number that is cursor is last on.

# %%
# Now lets add the result field

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)
    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

mainWindow.mainloop()

# %%
# Now for the time spinners

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59) #from and from_ are different
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)

mainWindow.mainloop()

# %%
# but it very close to the edge of the window, we will add padding,
# this will add padding both side of the widget like x or y(horizontal and vertical)

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59) #from and from_ are different
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59) #form & to is used when we dont have a concrete range
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)
#padding for the widget
timeFrame['padx']=36

mainWindow.mainloop()

# %%
# perfect, now lets add the date spinner

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)
#padding for the widget
timeFrame['padx']=36

#frame for date spinners
dateFrame = tkinter.Frame(mainWindow)
dateFrame.grid(row=4,column=0,sticky='new')
#Date labels
dayLabel = tkinter.Label(dateFrame,text="Day")
monthLabel = tkinter.Label(dateFrame,text="Month")
yearLabel = tkinter.Label(dateFrame,text="Year")
dayLabel.grid(row=0,column=0,sticky='w')
monthLabel.grid(row=0,column=1,sticky='w')
yearLabel.grid(row=0,column=2,sticky='w')
#Date Spinners
daySpin = tkinter.Spinbox(dateFrame,width=5,from_=1,to=31)
monthSpin = tkinter.Spinbox(dateFrame,width=5,values=("Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"))
yearSpin = tkinter.Spinbox(dateFrame,width=5,from_=2000,to=2099)
#In line 84, we could have added from and to but putting actual name is much more reasonable
daySpin.grid(row=1,column=0)
monthSpin.grid(row=1,column=1)
yearSpin.grid(row=1,column=2)

mainWindow.mainloop()

# %%
# Now lets make the "OK" & "Cancel" Button

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)
#padding for the widget
timeFrame['padx']=36

#frame for date spinners
dateFrame = tkinter.Frame(mainWindow)
dateFrame.grid(row=4,column=0,sticky='new')
#Date labels
dayLabel = tkinter.Label(dateFrame,text="Day")
monthLabel = tkinter.Label(dateFrame,text="Month")
yearLabel = tkinter.Label(dateFrame,text="Year")
dayLabel.grid(row=0,column=0,sticky='w')
monthLabel.grid(row=0,column=1,sticky='w')
yearLabel.grid(row=0,column=2,sticky='w')
#Date Spinners
daySpin = tkinter.Spinbox(dateFrame,width=5,from_=1,to=31)
monthSpin = tkinter.Spinbox(dateFrame,width=5,
    values=("Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"))
yearSpin = tkinter.Spinbox(dateFrame,width=5,from_=2000,to=2099)
daySpin.grid(row=1,column=0)
monthSpin.grid(row=1,column=1)
yearSpin.grid(row=1,column=2)

#Ok and Cancel Buttons
okButton = tkinter.Button(mainWindow,text="OK")
cancelButton = tkinter.Button(mainWindow,text="Cancel",command=mainWindow.quit())
#.destroy would be better here, as it stop the loop of the widget, .quit terminates the program
okButton.grid(row=4,column=3,sticky='e')
cancelButton.grid(row=4,column=4,sticky='w')

mainWindow.mainloop()

# %%
# one thing you'll notice that cancel dosent do anything if pressed, its a common mistake,
# the mistake is, when "Cancel" button is being pressed, quit is being called and it return None,
# thats why it dosent do anything.
# To fix this, we simply need to name the function, and when the Button is pressed the button will call the function.
# and secondly, lets change .quit to .destory

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)
#padding for the widget
timeFrame['padx']=36

#frame for date spinners
dateFrame = tkinter.Frame(mainWindow)
dateFrame.grid(row=4,column=0,sticky='new')
#Date labels
dayLabel = tkinter.Label(dateFrame,text="Day")
monthLabel = tkinter.Label(dateFrame,text="Month")
yearLabel = tkinter.Label(dateFrame,text="Year")
dayLabel.grid(row=0,column=0,sticky='w')
monthLabel.grid(row=0,column=1,sticky='w')
yearLabel.grid(row=0,column=2,sticky='w')
#Date Spinners
daySpin = tkinter.Spinbox(dateFrame,width=5,from_=1,to=31)
monthSpin = tkinter.Spinbox(dateFrame,width=5,
    values=("Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"))
yearSpin = tkinter.Spinbox(dateFrame,width=5,from_=2000,to=2099)
daySpin.grid(row=1,column=0)
monthSpin.grid(row=1,column=1)
yearSpin.grid(row=1,column=2)

#Ok and Cancel Buttons
okButton = tkinter.Button(mainWindow,text="OK")
cancelButton = tkinter.Button(mainWindow,text="Cancel",command=mainWindow.destroy)
okButton.grid(row=4,column=3,sticky='e')
cancelButton.grid(row=4,column=4,sticky='w')

mainWindow.mainloop()

# %%
# Perfect, and lastly the lets just add a bit of padding to all around the window,
# so that not everything is flushed against the window.

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')
mainWindow['padx']=8  #added padding around the window

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=1)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=3)
mainWindow.columnconfigure(3,weight=3)
mainWindow.columnconfigure(4,weight=3)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)
#padding for the widget
timeFrame['padx']=36

#frame for date spinners
dateFrame = tkinter.Frame(mainWindow)
dateFrame.grid(row=4,column=0,sticky='new')
#Date labels
dayLabel = tkinter.Label(dateFrame,text="Day")
monthLabel = tkinter.Label(dateFrame,text="Month")
yearLabel = tkinter.Label(dateFrame,text="Year")
dayLabel.grid(row=0,column=0,sticky='w')
monthLabel.grid(row=0,column=1,sticky='w')
yearLabel.grid(row=0,column=2,sticky='w')
#Date Spinners
daySpin = tkinter.Spinbox(dateFrame,width=5,from_=1,to=31)
monthSpin = tkinter.Spinbox(dateFrame,width=5,
    values=("Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"))
yearSpin = tkinter.Spinbox(dateFrame,width=5,from_=2000,to=2099)
daySpin.grid(row=1,column=0)
monthSpin.grid(row=1,column=1)
yearSpin.grid(row=1,column=2)

#Ok and Cancel Buttons
okButton = tkinter.Button(mainWindow,text="OK")
cancelButton = tkinter.Button(mainWindow,text="Cancel",command=mainWindow.destroy)
okButton.grid(row=4,column=3,sticky='e')
cancelButton.grid(row=4,column=4,sticky='w')

mainWindow.mainloop()

# %%
#(Check out the Advanced GUI Widget Part 3 for a detailed explanation on weights and how it effects widgets)
# And lets change the weights

import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')
mainWindow['padx']=8  #added padding around the window

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)
#changing the weigths
mainWindow.columnconfigure(0,weight=100)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=1000)
mainWindow.columnconfigure(3,weight=600)
mainWindow.columnconfigure(4,weight=1000)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)
#padding for the widget
timeFrame['padx']=36

#frame for date spinners
dateFrame = tkinter.Frame(mainWindow)
dateFrame.grid(row=4,column=0,sticky='new')
#Date labels
dayLabel = tkinter.Label(dateFrame,text="Day")
monthLabel = tkinter.Label(dateFrame,text="Month")
yearLabel = tkinter.Label(dateFrame,text="Year")
dayLabel.grid(row=0,column=0,sticky='w')
monthLabel.grid(row=0,column=1,sticky='w')
yearLabel.grid(row=0,column=2,sticky='w')
#Date Spinners
daySpin = tkinter.Spinbox(dateFrame,width=5,from_=1,to=31)
monthSpin = tkinter.Spinbox(dateFrame,width=5,
    values=("Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"))
yearSpin = tkinter.Spinbox(dateFrame,width=5,from_=2000,to=2099)
daySpin.grid(row=1,column=0)
monthSpin.grid(row=1,column=1)
yearSpin.grid(row=1,column=2)

#Ok and Cancel Buttons
okButton = tkinter.Button(mainWindow,text="OK")
cancelButton = tkinter.Button(mainWindow,text="Cancel",command=mainWindow.destroy)
okButton.grid(row=4,column=3,sticky='e')
cancelButton.grid(row=4,column=4,sticky='w')

mainWindow.mainloop()

# %%
# So this is the final code for our widget

# %%
import tkinter
import os

mainWindow = tkinter.Tk()

mainWindow.title("Grid Demo")
mainWindow.geometry('640x480')
mainWindow['padx']=8

label = tkinter.Label(mainWindow, text="Tkinter Grid Demo")
label.grid(row=0, column=0, columnspan=3)

mainWindow.columnconfigure(0,weight=100)
mainWindow.columnconfigure(1,weight=1)
mainWindow.columnconfigure(2,weight=1000)
mainWindow.columnconfigure(3,weight=600)
mainWindow.columnconfigure(4,weight=1000)

mainWindow.rowconfigure(0,weight=1)
mainWindow.rowconfigure(1,weight=10)
mainWindow.rowconfigure(2,weight=1)
mainWindow.rowconfigure(3,weight=3)
mainWindow.rowconfigure(4,weight=3)

#frame for list
fileList = tkinter.Listbox(mainWindow)
fileList.grid(row=1,column=0, sticky = 'nsew', rowspan =2)
fileList.config(border=2, relief='sunken')
for zone in os.listdir('/Windows/System32'):
    fileList.insert(tkinter.END,zone)

#scroll bar    
listScroll = tkinter.Scrollbar(mainWindow, orient=tkinter.VERTICAL, command = fileList.yview)
listScroll.grid(row=1,column=1,sticky='nsw',rowspan=2)
fileList['yscrollcommand'] = listScroll.set

#File Details Frame
optionFrame = tkinter.LabelFrame(mainWindow,text="File Details") 
optionFrame.grid(row=1, column =2,sticky='ne')
rbValue = tkinter.IntVar()
rbValue.set(3)
#radio buttons
radio1 = tkinter.Radiobutton(optionFrame, text="Filename", value=1, variable=rbValue)
radio2 = tkinter.Radiobutton(optionFrame, text="Path", value=2, variable=rbValue)
radio3 = tkinter.Radiobutton(optionFrame, text="Timestamp", value=3, variable=rbValue)
radio1.grid(row=0,column=0,sticky='w')
radio2.grid(row=1,column=0,sticky='w')
radio3.grid(row=2,column=0,sticky='w')

#result field
resultLabel = tkinter.Label(mainWindow,text="Result")
resultLabel.grid(row=2,column=2,sticky='nw')
result = tkinter.Entry(mainWindow)
result.grid(row=2,column=2,sticky='sw')

#frame for time spinners
timeFrame = tkinter.LabelFrame(mainWindow,text="Time")
timeFrame.grid(row=3,column=0,sticky='new')
#Time spinners
hourSpinner = tkinter.Spinbox(timeFrame, width=2, values=tuple(range(0,24)))
minuteSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
secondSpinner = tkinter.Spinbox(timeFrame, width=2, from_=0, to=59)
hourSpinner.grid(row=0,column=0)
tkinter.Label(timeFrame,text=':').grid(row=0,column=1)
minuteSpinner.grid(row=0,column=2)
tkinter.Label(timeFrame,text=':').grid(row=0,column=3)
secondSpinner.grid(row=0,column=4)
#padding for the widget
timeFrame['padx']=36

#frame for date spinners
dateFrame = tkinter.Frame(mainWindow)
dateFrame.grid(row=4,column=0,sticky='new')
#Date labels
dayLabel = tkinter.Label(dateFrame,text="Day")
monthLabel = tkinter.Label(dateFrame,text="Month")
yearLabel = tkinter.Label(dateFrame,text="Year")
dayLabel.grid(row=0,column=0,sticky='w')
monthLabel.grid(row=0,column=1,sticky='w')
yearLabel.grid(row=0,column=2,sticky='w')
#Date Spinners
daySpin = tkinter.Spinbox(dateFrame,width=5,from_=1,to=31)
monthSpin = tkinter.Spinbox(dateFrame,width=5,
    values=("Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"))
yearSpin = tkinter.Spinbox(dateFrame,width=5,from_=2000,to=2099)
daySpin.grid(row=1,column=0)
monthSpin.grid(row=1,column=1)
yearSpin.grid(row=1,column=2)

#Ok and Cancel Buttons
okButton = tkinter.Button(mainWindow,text="OK")
cancelButton = tkinter.Button(mainWindow,text="Cancel",command=mainWindow.destroy)
okButton.grid(row=4,column=3,sticky='e')
cancelButton.grid(row=4,column=4,sticky='w')

mainWindow.mainloop()

# %%
# CHALLENGE

# %%
# Write a GUI program to create a simple calculator
# layout that looks like the screenshot.
#
# Try to be as Pythonic as possible - it's ok if you
# end up writing repeated Button and Grid statements,
# but consider using lists and a for loop.
#
# There is no need to store the buttons in variables.
#
# As an optional extra, refer to the documentation to
# work out how to use minsize() to prevent your window
# from being shrunk so that the widgets vanish from view.
#
# Hint: You may want to use the widgets .winfo_height() and
# winfo_width() methods, in which case you should know that
# they will not return the correct results unless the window
# has been forced to draw the widgets by calling its .update()
# method first.
#
# If you are using Windows you will probably find that the
# width is already constrained and can't be resized too small.
# The height will still need to be constrained, though.

# %% [markdown]
# ![11.7-CalculatorScreenshot.png](attachment:11.7-CalculatorScreenshot.png)

# %%
try:
    import tkinter
except ImportError: # python 2
    import Tkinter as tkinter

keys = [[('C', 1), ('CE', 1)],
        [('7', 1), ('8', 1), ('9', 1), ('+', 1)],
        [('4', 1), ('5', 1), ('6', 1), ('-', 1)],
        [('1', 1), ('2', 1), ('3', 1), ('*', 1)],
        [('0', 1), ('=', 2), ('/', 1)],
        ]

mainWindowPadding = 8

mainWindow = tkinter.Tk()
mainWindow.title("Calculator")
mainWindow.geometry('640x480-8-200')
mainWindow['padx'] = mainWindowPadding

result = tkinter.Entry(mainWindow)
result.grid(row=0, column=0, sticky='nsew')

keyPad = tkinter.Frame(mainWindow)
keyPad.grid(row=1, column=0, sticky='nsew')

row = 0
for keyRow in keys:
    col = 0
    for key in keyRow:
        tkinter.Button(keyPad, text=key[0]).grid(row=row, column=col, columnspan=key[1], sticky=tkinter.E + tkinter.W)
        col += key[1]
    row += 1

mainWindow.update()
mainWindow.minsize(keyPad.winfo_width() + mainWindowPadding, result.winfo_height() + keyPad.winfo_height())
mainWindow.maxsize(keyPad.winfo_width() + 50 + mainWindowPadding, result.winfo_height() + 50 + keyPad.winfo_height())

mainWindow.mainloop()

# %%
# Now the window is there, but there is no functionality

# %%
# Now the calculator can't do anything, unless we can define our own functions
# So lets now look at functions

# %% [markdown]
# ### FUNCTIONS

# %%
#defining the function
def python_food():
     print("tea and coffee")
        
#calling the function
python_food()
# Out:
# tea and coffee

# %%
# One thing is important here,
# All Python functions return a result
# If there is no result it will return None

# %%
def python_food():
    print("tea and coffee")
    
#now instead of calling the function, ill pass the function call as an argument
print(python_food())
# Out:
# tea and coffee
# None

# %%
# Although passing a function call as an argument will most likely result in None,
# but it still demonstrate the result we are trying to achieve.

# %%
# Now lets make the python defination example a little bit more intresting
# we will try to center the text

def python_food():
    width = 80
    text = "Tea and Coffee"
    left_margin = (width -len(text)) // 2
    print(" " * left_margin, text)
    
python_food()
# Out:
#                                   Tea and Coffee

# %%
# And if this the left margin is correctly working or not we can check it by

def center_text(text):
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text("Tea, Coffee, Biscuits and Cakes")
# Out:
#                                   Tea and Coffee
#                              Tea, Coffee and Biscuits
#                          Tea, Coffee, Biscuits and Cakes

# %%
# As you can see its working perfectly
# But if someone passes a number, the code will run into an error

def center_text(text):
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
# Out:
#                                   Tea and Coffee
#                              Tea, Coffee and Biscuits
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-72752a526167> in <module>
#       8 center_text("Tea and Coffee")
#       9 center_text("Tea, Coffee and Biscuits")
# ---> 10 center_text(45)
#      11 center_text("Tea, Coffee, Biscuits and Cakes")
#
# <ipython-input-3-72752a526167> in center_text(text)
#       3
#       4 def center_text(text):
# ----> 5     left_margin = (80-len(text)) // 2
#       6     print(" " * left_margin,text)
#       7
#
# TypeError: object of type 'int' has no len()

# %%
# So we cant really use 'len' against numbers, we need to change it to string for it to work

def center_text(text):
    text = str(text) #changing anything that is being passed as string
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
# Out:
#                                   Tea and Coffee
#                              Tea, Coffee and Biscuits
#                                         45
#                          Tea, Coffee, Biscuits and Cakes

# %%
print("first", "second", 3,4, "fifth")
# Out:
# first second 3 4 fifth

# %%
# As you can see, the print function already puts a space between the arguments.
# We can implement this in our center text function

# The way we can do this, by using * and iterating through the argument list
# and concatenate all the arguments in one string, before centering it.

# %%
def center_text(*args): #by specifying * we denote that there are multiple arguments
    text = "" # as there are multiple arguments, we have to start with an empty string
    for arg in args: #using the for loop to add the arguments in one string
        text += str(arg) + " "
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
# Out:
#                                  Tea and Coffee
#                             Tea, Coffee and Biscuits
#                                        45
#                          Tea, Coffee, Biscuits and Cakes

# %%
# As you can see it still works with our previous arguments, and lets try it with multiple arguements

center_text("first", "second", 3,4, "fifth")
# Out:
#                              first second 3 4 fifth

# %%
#(One thing to keep in my mind is that, string concatenation is not very efficient, using list comprehension is better)

# %%
# You might say we can use '.join' instead of using 'for' loop
# But if we implement that, we can see

def center_text(*args):
    text = " ".join(args) 
#     for arg in args: 
#         text += str(arg) + " "
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
# Out:
#                                   Tea and Coffee
#                              Tea, Coffee and Biscuits
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-be7ea40eac8f> in <module>
#      11 center_text("Tea and Coffee")
#      12 center_text("Tea, Coffee and Biscuits")
# ---> 13 center_text(45)
#      14 center_text("Tea, Coffee, Biscuits and Cakes")
#
# <ipython-input-8-be7ea40eac8f> in center_text(*args)
#       3
#       4 def center_text(*args):
# ----> 5     text = " ".join(args)
#       6 #     for arg in args:
#       7 #         text += str(arg) + " "
#
# TypeError: sequence item 0: expected str instance, int found

# %%
# We will see that, it only works with string methods and not with int

# %%
# But if we do .join(str(args)) 

def center_text(*args):
    text = " ".join(str(args)) 
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
# Out:
#                       ( ' T e a   a n d   C o f f e e ' , )
#             ( ' T e a ,   C o f f e e   a n d   B i s c u i t s ' , )
#                                     ( 4 5 , )
#      ( ' T e a ,   C o f f e e ,   B i s c u i t s   a n d   C a k e s ' , )

# %%
# We get completely different results

# %%
print()
# In Jupytet Notebook, if you hover over the method and press "Shift+Tab" twice, the documentation will open up.

# %%
# What we can do now is that to make our 'center_text' function behave in the same way as print
# by declaring the same named parameter then passing most of the arguments straight to the print function

def center_text(*args, sep=' ', end='\n', file=None, flush=False):
    text= ""
    for arg in args:
        text += str(arg) + sep #We mention the sep here, instead of the last line's print
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text, end=end, file=file, flush=flush)# this may seem odd
    # but think of it like the value that we passed in the arguments, are used in the print fucntion
    # like in the func def 'end=\n', the \n is passed in the 'end' variable in the 'print' method's 'end' argument.
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
center_text("first", "second", 3,4, "fifth", sep=':')
# Out:
#                                  Tea and Coffee
#                             Tea, Coffee and Biscuits
#                                        45
#                          Tea, Coffee, Biscuits and Cakes
#                              first:second:3:4:fifth:

# %%
# One problem is the ':' in the end, to fix it, we need list comprehension, that will make removing the ':' easier
# We can do it here too but thats a lot of work

# And also if you still didnt understood what is happening in the func def and the print func, lets change the names
# So it will be easier to understand

def center_text(*args, sep=' ', end_char='\n', centered_file=None, flush_me=False):
    text= ""
    for arg in args:
        text += str(arg) + sep
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text, end=end_char, file=centered_file, flush=flush_me)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
center_text("first", "second", 3,4, "fifth", sep=':')
# Out:
#                                  Tea and Coffee
#                             Tea, Coffee and Biscuits
#                                        45
#                          Tea, Coffee, Biscuits and Cakes
#                              first:second:3:4:fifth:

# %%
# This is good, if you have trouble understanding this but this cretes a different signature
# A signature is when two functions that take the same parameters will have same signature
# Here the print and print from Python have different signature, 
# So what we will do to we will revert back, so both of them will have same signature

def center_text(*args, sep=' ', end='\n', file=None, flush=False):
    text= ""
    for arg in args:
        text += str(arg) + sep
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text, end=end, file=file, flush=flush)
    
center_text("Tea and Coffee")
center_text("Tea, Coffee and Biscuits")
center_text(45)
center_text("Tea, Coffee, Biscuits and Cakes")
center_text("first", "second", 3,4, "fifth", sep=':')
# Out:
#                                  Tea and Coffee
#                             Tea, Coffee and Biscuits
#                                        45
#                          Tea, Coffee, Biscuits and Cakes
#                              first:second:3:4:fifth:

# %%
# Now lets change the course for center_text, so we can sent the output to a file

def center_text(*args, sep=' ', end='\n', file=None, flush=False):
    text= ""
    for arg in args:
        text += str(arg) + sep
    left_margin = (80-len(text)) // 2
    print(" " * left_margin,text, end=end, file=file, flush=flush)
    
with open("centered",mode='w') as centered_file:
# To indent many lines at once, select all line and press 'Tab'
    center_text("Tea and Coffee",file=centered_file)
    center_text("Tea, Coffee and Biscuits",file=centered_file)
    center_text(45,file=centered_file)
    center_text("Tea, Coffee, Biscuits and Cakes",file=centered_file)
    center_text("first", "second", 3,4, "fifth", sep=':',file=centered_file)

# %%
# This will create file name 'centered' where you are working. For me,

# %% [markdown]
# ![Screenshot%20%2827%29.png](attachment:Screenshot%20%2827%29.png)

# %%
# Now there was no 'flush' parameter in Python 3.2, so we wouldn't have known to put a centered_text as flush parameter
# So what we can do is to write center_text so that it returns a required string without actually printing it
# And this is a good opportunity to understand about returning values from function

def center_text(*args, sep=' '):
    text= ""
    for arg in args:
        text += str(arg) + sep
    left_margin = (80-len(text)) // 2
    return " " * left_margin + text

# To un-indent a line(s), use 'Shift+Tab'
print(center_text("Tea and Coffee"))
print(center_text("Tea, Coffee and Biscuits"))
print(center_text(45))
print(center_text("Tea, Coffee, Biscuits and Cakes"))
print(center_text("first", "second", 3,4, "fifth", sep=':'))
# Out:
#                                 Tea and Coffee
#                            Tea, Coffee and Biscuits
#                                       45
#                         Tea, Coffee, Biscuits and Cakes
#                             first:second:3:4:fifth:

# %%
# So what can help and will be a little less confusing, is assigning the return results in variables

def center_text(*args, sep=' '):
    text= ""
    for arg in args:
        text += str(arg) + sep
    left_margin = (80-len(text)) // 2
    return " " * left_margin + text

s1=center_text("Tea and Coffee")
print(s1)
s2=center_text("Tea, Coffee and Biscuits")
print(s2)
s3=center_text(45)
print(s3)
s4=center_text("Tea, Coffee, Biscuits and Cakes")
print(s4)
s5=center_text("first", "second", 3,4, "fifth", sep=':')
print(s5)
# Out:
#                                 Tea and Coffee
#                            Tea, Coffee and Biscuits
#                                       45
#                         Tea, Coffee, Biscuits and Cakes
#                             first:second:3:4:fifth:

# %%
# And to print the result on a file,

def center_text(*args, sep=' '):
    text= ""
    for arg in args:
        text += str(arg) + sep
    left_margin = (80-len(text)) // 2
    return " " * left_margin + text

with open("print_centered", "w") as menu:
    s1=center_text("Tea and Coffee")
    print(s1,file=menu)
    s2=center_text("Tea, Coffee and Biscuits")
    print(s2,file=menu)
    print(center_text(45),file=menu)
    print(center_text("Tea, Coffee, Biscuits and Cakes"),file=menu)
    s5=center_text("first", "second", 3,4, "fifth", sep=':')
    print(s5,file=menu)
    
# The reason we assigned a variable to some and printed some, to show the both kind of methods

# %% [markdown]
# ![Screenshot%20%2828%29.png](attachment:Screenshot%20%2828%29.png)

# %%
# lets now create a func for Parabola

def parabola(x):
    y = x * x
    return y

for x in range(-100,100):
    y = parabola(x)
    print(y)
# Out:
# 10000
# 9801
# 9604
# 9409
# 9216
# 9025
# 8836
# 8649
# 8464
# 8281
# 8100
# 7921
# 7744
# 7569
# 7396
# 7225
# 7056
# 6889
# 6724
# 6561
# 6400
# 6241
# 6084
# 5929
# 5776
# 5625
# 5476
# 5329
# 5184
# 5041
# 4900
# 4761
# 4624
# 4489
# 4356
# 4225
# 4096
# 3969
# 3844
# 3721
# 3600
# 3481
# 3364
# 3249
# 3136
# 3025
# 2916
# 2809
# 2704
# 2601
# 2500
# 2401
# 2304
# 2209
# 2116
# 2025
# 1936
# 1849
# 1764
# 1681
# 1600
# 1521
# 1444
# 1369
# 1296
# 1225
# 1156
# 1089
# 1024
# 961
# 900
# 841
# 784
# 729
# 676
# 625
# 576
# 529
# 484
# 441
# 400
# 361
# 324
# 289
# 256
# 225
# 196
# 169
# 144
# 121
# 100
# 81
# 64
# 49
# 36
# 25
# 16
# 9
# 4
# 1
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# ...

# %%
# And you can see on the output that, how the numbers rise and fall and rise again, creating a parabola,
# But it would be more helpful, if we could plot the point in a graph and visualize it

# %%
# Now to plot a graph we will use the Tkinter 

import tkinter

def parabola(x):
    y = x * x / 100 #This /100 will prevent 'y' values from running off the screen
    return y

# To draw axes in tkinter, first, In tkinter, the (0,0) is in the top left corner of the window,
# and we basically bring it down and to the right and making the (0,0) in the center of the window
# and we need to draw lines to show the axes
def draw_axes(canvas): 
    canvas.update()
#canvas.update make sure that we can actually access the width and height of the window,
# and also when you use winfo you need to update the canvas.
    x_origin = canvas.winfo_width() / 2
    y_origin = canvas.winfo_height() / 2
    canvas.configure(scrollregion = (-x_origin, -y_origin, x_origin, y_origin))
    canvas.create_line(-x_origin,0,x_origin,0, fill="black")
    canvas.create_line(0,y_origin,0, -y_origin,fill="black")

# There is no method where we can plot dots in a canvas, but we can achieve the same result by drawing a line of length 1
def plot(canvas,x,y):
    canvas.create_line(x, y, x+1, y+1, fill='red')

mainWindow = tkinter.Tk()

mainWindow.title("Parabola")
mainWindow.geometry("640x480")

canvas = tkinter.Canvas(mainWindow, width=640, height=480)
canvas.grid(row=0,column=0)

draw_axes(canvas)

for x in range(-100,100):
    y = parabola(x)
    plot(canvas, x, -y) # instead of printing, we will plot
                        # and the reason we use -y here, because here, the +ve 'y' values tend to downwards on the graph
                        # but traditionally we know the the +ve 'y' values go upwards
    
mainWindow.mainloop()

# %% [markdown]
# ![Screenshot%20%2829%29.png](attachment:Screenshot%20%2829%29.png)

# %%
# Here the parabolic function isn't really doing all it can do thought at the moment,
# the program needs to loop through the values it returns,
# in order to print a parabola.
# So, wouldn't it be more useful if the function plotted the points
# and all we have to tell how big the parabola should be and give it a canvas to draw on.

# %%
import tkinter

def parabola(page, size):
    for x in range(-size,size):
        y = x * x / size
        plot(page,x,y)

def draw_axes(page):
    page.update()
    x_origin = page.winfo_width() / 2
    y_origin = page.winfo_height() / 2
    page.configure(scrollregion=(-x_origin, -y_origin, x_origin, y_origin))
    page.create_line(-x_origin, 0, x_origin, 0, fill="black")
    page.create_line(0, y_origin, 0, -y_origin, fill="black")
    print(locals())
    
def plot(page, x, y):
    page.create_line(x, -y, x + 1, -y + 1, fill="red")
    
mainWindow = tkinter.Tk()

mainWindow.title("Parabola")
mainWindow.geometry("640x480")

canvas = tkinter.Canvas(mainWindow, width=640, height=480)
canvas.grid(row=0, column=0)

draw_axes(canvas)

parabola(canvas, 100)
parabola(canvas, 200)

mainWindow.mainloop()
# Out:
# {'page': <tkinter.Canvas object .!canvas>, 'x_origin': 322.0, 'y_origin': 242.0}

# %%
# Now at the moment the loop calculates the value of y you can see
# on line 4 for both positive and negative values of x but the parabola is symmetric about
# the y axis so there's really no point calculating y twice
#
# So what we need to do is:

import tkinter

def parabola(page, size):
    for x in range(size): # changing the -size to size to only size, as we only need to calculate it once
        y = x * x / size
        plot(page,x,y)
        plot(page,-x,y) # we just add a second plot
        #its the same thing, but we are cutting down on process time by going through the loop only once

def draw_axes(page):
    page.update()
    x_origin = page.winfo_width() / 2
    y_origin = page.winfo_height() / 2
    page.configure(scrollregion=(-x_origin, -y_origin, x_origin, y_origin))
    page.create_line(-x_origin, 0, x_origin, 0, fill="black")
    page.create_line(0, y_origin, 0, -y_origin, fill="black")
    print(locals())
    
def plot(page, x, y):
    page.create_line(x, -y, x + 1, -y + 1, fill="red")
    
mainWindow = tkinter.Tk()

mainWindow.title("Parabola")
mainWindow.geometry("640x480")

canvas = tkinter.Canvas(mainWindow, width=640, height=480)
canvas.grid(row=0, column=0)

draw_axes(canvas)

parabola(canvas, 100)
parabola(canvas, 200)

mainWindow.mainloop()
# Out:
# {'page': <tkinter.Canvas object .!canvas>, 'x_origin': 322.0, 'y_origin': 242.0}

# %% [markdown]
# ![Screenshot%20%2831%29.png](attachment:Screenshot%20%2831%29.png)

# %%
# Lets add some circles for a bit of practice
import math
import tkinter

def parabola(page, size):
    for x in range(size):
        y = x * x / size
        plot(page,x,y)
        plot(page,-x,y)
        
def circle(page, radius, g, h):
    for x in range(g, g + radius):
        y = h + (math.sqrt(radius ** 2 - ((x-g) ** 2)))
        plot(page, x, y)
        plot(page, x, 2 * h - y)
        plot(page, 2 * g - x, y)
        plot(page, 2 * g - x, 2 * h  - y)

def draw_axes(page):
    page.update()
    x_origin = page.winfo_width() / 2
    y_origin = page.winfo_height() / 2
    page.configure(scrollregion=(-x_origin, -y_origin, x_origin, y_origin))
    page.create_line(-x_origin, 0, x_origin, 0, fill="black")
    page.create_line(0, y_origin, 0, -y_origin, fill="black")
    print(locals())
    
def plot(page, x, y):
    page.create_line(x, -y, x + 1, -y + 1, fill="red")
    
mainWindow = tkinter.Tk()

mainWindow.title("Parabola")
mainWindow.geometry("640x480")

canvas = tkinter.Canvas(mainWindow, width=640, height=480)
canvas.grid(row=0, column=0)

draw_axes(canvas)

parabola(canvas, 100)
parabola(canvas, 200)
# now that our circle function is defined, we can call it few more times, to make a pattern
circle(canvas, 100, 100, 100)
circle(canvas, 100, 100, -100)
circle(canvas, 100, -100, 100)
circle(canvas, 100, -100, -100)
circle(canvas, 10, 30, 30)
circle(canvas, 10, 30, -30)
circle(canvas, 10, -30, 30)
circle(canvas, 10, -30, -30)
circle(canvas, 30, 0, 0)

mainWindow.mainloop()
# Out:
# {'page': <tkinter.Canvas object .!canvas>, 'x_origin': 322.0, 'y_origin': 242.0}

# %%
# And you can see the lines get vague around the edges of the circles, but that because of the x,
# and we cant have, decimal places so, to fill it.
# But to fix it we can multiply the range up, so more values are used, an scale each values back down again

# %%
import math
import tkinter

def parabola(page, size):
    for x in range(size):
        y = x * x / size
        plot(page,x,y)
        plot(page,-x,y)
        
def circle(page, radius, g, h):
    for x in range(g * 100, (g + radius)*100):
        x /= 100 # to scale down the values so it can be plotted
        y = h + (math.sqrt(radius ** 2 - ((x-g) ** 2)))
        plot(page, x, y)
        plot(page, x, 2 * h - y)
        plot(page, 2 * g - x, y)
        plot(page, 2 * g - x, 2 * h  - y)

def draw_axes(page):
    page.update()
    x_origin = page.winfo_width() / 2
    y_origin = page.winfo_height() / 2
    page.configure(scrollregion=(-x_origin, -y_origin, x_origin, y_origin))
    page.create_line(-x_origin, 0, x_origin, 0, fill="black")
    page.create_line(0, y_origin, 0, -y_origin, fill="black")
    print(locals())
    
def plot(page, x, y):
    page.create_line(x, -y, x + 1, -y + 1, fill="red")
    
mainWindow = tkinter.Tk()

mainWindow.title("Parabola")
mainWindow.geometry("640x480")

canvas = tkinter.Canvas(mainWindow, width=640, height=480)
canvas.grid(row=0, column=0)

draw_axes(canvas)

parabola(canvas, 100)
parabola(canvas, 200)
circle(canvas, 100, 100, 100)
circle(canvas, 100, 100, -100)
circle(canvas, 100, -100, 100)
circle(canvas, 100, -100, -100)
circle(canvas, 10, 30, 30)
circle(canvas, 10, 30, -30)
circle(canvas, 10, -30, 30)
circle(canvas, 10, -30, -30)
circle(canvas, 30, 0, 0)

mainWindow.mainloop()
# Out:
# {'page': <tkinter.Canvas object .!canvas>, 'x_origin': 322.0, 'y_origin': 242.0}

# %%
# So as you can see it alot better, but it took significantly longer

# %%
# Now instead of using this complex method of calculating circles, we can use the .create_oval method 
# to create a circle, and we only have to add one line.

import math
import tkinter

def parabola(page, size):
    for x in range(size):
        y = x * x / size
        plot(page,x,y)
        plot(page,-x,y)
        
def circle(page, radius, g, h):
    page.create_oval(g + radius, h + radius, g - radius, h - radius, outline ='red', width=2)
#     for x in range(g * 100, (g + radius)*100):
#         x /= 100
#         y = h + (math.sqrt(radius ** 2 - ((x-g) ** 2)))
#         plot(page, x, y)
#         plot(page, x, 2 * h - y)
#         plot(page, 2 * g - x, y)
#         plot(page, 2 * g - x, 2 * h  - y)

def draw_axes(page):
    page.update()
    x_origin = page.winfo_width() / 2
    y_origin = page.winfo_height() / 2
    page.configure(scrollregion=(-x_origin, -y_origin, x_origin, y_origin))
    page.create_line(-x_origin, 0, x_origin, 0, fill="black")
    page.create_line(0, y_origin, 0, -y_origin, fill="black")
    print(locals())
    
def plot(page, x, y):
    page.create_line(x, -y, x + 1, -y + 1, fill="red")
    
mainWindow = tkinter.Tk()

mainWindow.title("Parabola")
mainWindow.geometry("640x480")

canvas = tkinter.Canvas(mainWindow, width=640, height=480)
canvas.grid(row=0, column=0)

draw_axes(canvas)

parabola(canvas, 100)
parabola(canvas, 200)
circle(canvas, 100, 100, 100)
circle(canvas, 100, 100, -100)
circle(canvas, 100, -100, 100)
circle(canvas, 100, -100, -100)
circle(canvas, 10, 30, 30)
circle(canvas, 10, 30, -30)
circle(canvas, 10, -30, 30)
circle(canvas, 10, -30, -30)
circle(canvas, 30, 0, 0)

mainWindow.mainloop()
# Out:
# {'page': <tkinter.Canvas object .!canvas>, 'x_origin': 322.0, 'y_origin': 242.0}

# %%
# As you can see we get the same result and faster this time

# %%
#MINI CHALLENGE

# %%
# Modify the circle function so that it allows the color of the circle to be specified
# and defaults to red if a color is not specified.(See named parameters)

import math
import tkinter

def parabola(page, size):
    for x in range(size):
        y = x * x / size
        plot(page,x,y)
        plot(page,-x,y)
        
def circle(page, radius, g, h, colour='red'): #thats all we need to do
    page.create_oval(g + radius, h + radius, g - radius, h - radius, outline =colour, width=2)

def draw_axes(page):
    page.update()
    x_origin = page.winfo_width() / 2
    y_origin = page.winfo_height() / 2
    page.configure(scrollregion=(-x_origin, -y_origin, x_origin, y_origin))
    page.create_line(-x_origin, 0, x_origin, 0, fill="black")
    page.create_line(0, y_origin, 0, -y_origin, fill="black")
    print(locals())
    
def plot(page, x, y):
    page.create_line(x, -y, x + 1, -y + 1, fill="red")
    
mainWindow = tkinter.Tk()

mainWindow.title("Parabola")
mainWindow.geometry("640x480")

canvas = tkinter.Canvas(mainWindow, width=640, height=480)
canvas.grid(row=0, column=0)

draw_axes(canvas)

parabola(canvas, 100)
parabola(canvas, 200)
# and we can check it by
circle(canvas, 100, 100, 100,'green')
circle(canvas, 100, 100, -100,'blue')
circle(canvas, 100, -100, 100,'black')
circle(canvas, 100, -100, -100,'yellow')
circle(canvas, 10, 30, 30)
circle(canvas, 10, 30, -30)
circle(canvas, 10, -30, 30)
circle(canvas, 10, -30, -30)
circle(canvas, 30, 0, 0)

mainWindow.mainloop()
# Out:
# {'page': <tkinter.Canvas object .!canvas>, 'x_origin': 322.0, 'y_origin': 242.0}

# %% [markdown]
# #### (CHECK OUT GLOBAL VARIABLES & KEYWORDS, IMPORTING IN FUCNTIONS & UNDERSCORES AND SCOPE)

# %%
# NAMESPACES, SCOPE AND RECURSSION

# %%
# Recursive Functions: A function that calls itself

#but lets first see how a iterative function works
def fact(n):
    #calculate n! iteratively
    result = 1
    for f in range(2, n+1):
        result *= f
    return result

for i in range(20):
    print(i, fact(i))
# Out:
# 0 1
# 1 1
# 2 2
# 3 6
# 4 24
# 5 120
# 6 720
# 7 5040
# 8 40320
# 9 362880
# 10 3628800
# 11 39916800
# 12 479001600
# 13 6227020800
# 14 87178291200
# 15 1307674368000
# 16 20922789888000
# 17 355687428096000
# 18 6402373705728000
# 19 121645100408832000

# %%
# now lets see how a recursive function works with the same factorial example

def factorial(n):
    # n! can also be defined as n * (n-1)
    # calculates n! recursively
    if n <= 1:
        return 1
    else:
        return n * factorial(n-1)
    
for i in range(20):
    print(i,factorial(i))
# Out:
# 0 1
# 1 1
# 2 2
# 3 6
# 4 24
# 5 120
# 6 720
# 7 5040
# 8 40320
# 9 362880
# 10 3628800
# 11 39916800
# 12 479001600
# 13 6227020800
# 14 87178291200
# 15 1307674368000
# 16 20922789888000
# 17 355687428096000
# 18 6402373705728000
# 19 121645100408832000

# %% [markdown]
# ![Screenshot%20%2832%29.png](attachment:Screenshot%20%2832%29.png)

# %%
# Lets run a Fibonacci series recursively

# %%
def fib(n):
    """F(n) = F(n-1) + F(n-2)"""
    if n < 2:
        return n
    else:
        return fib(n-1) + fib(n-2)
    
for i in range(36):
    print(i, fib(i))
# Out:
# 0 0
# 1 1
# 2 1
# 3 2
# 4 3
# 5 5
# 6 8
# 7 13
# 8 21
# 9 34
# 10 55
# 11 89
# 12 144
# 13 233
# 14 377
# 15 610
# 16 987
# 17 1597
# 18 2584
# 19 4181
# 20 6765
# 21 10946
# 22 17711
# 23 28657
# 24 46368
# 25 75025
# 26 121393
# 27 196418
# 28 317811
# 29 514229
# 30 832040
# 31 1346269
# 32 2178309
# 33 3524578
# 34 5702887
# 35 9227465

# %%
# As you can see, it takes a while after 30 to return the fibonacci number,
# because it has to calculate twice, onece for f(n-1) and second for f(n-2)

# A iterative approach will be best

# %%
def fibonacci(n):
    if n == 0:
        result = 0
    elif  n == 1:
        result = 1
    else:
        n_minus1 = 1
        n_minus2 = 0
        for f in range(1, n):
            result = n_minus2 + n_minus1
            n_minus2 = n_minus1
            n_minus1 = result
    return result

for i in range(36):
    print(i, fibonacci(i))
# Out:
# 0 0
# 1 1
# 2 1
# 3 2
# 4 3
# 5 5
# 6 8
# 7 13
# 8 21
# 9 34
# 10 55
# 11 89
# 12 144
# 13 233
# 14 377
# 15 610
# 16 987
# 17 1597
# 18 2584
# 19 4181
# 20 6765
# 21 10946
# 22 17711
# 23 28657
# 24 46368
# 25 75025
# 26 121393
# 27 196418
# 28 317811
# 29 514229
# 30 832040
# 31 1346269
# 32 2178309
# 33 3524578
# 34 5702887
# 35 9227465

# %%
# So in some cases recursive will be easier, and in the some cases iterative will be easier

# %%
# One the places where recursive is quite useful when working with files or getting a directory listing for
# a computer file system
# Modern file system are recursive in sense that the directory, can itself contain other directories,
# so once the function listed all the other objects in one directory, it can call itself again for all the objects
# that are themselves directories, so thats one the good reasons in using recursive function

# %%
# lets list the files in the OS

import os

listing =  os.walk('.') #walk is predefined method that list all the directory in a file system
for root,directories,files in listing:
    print(root)
    for d in directories:
        print(d)
    for f in files:
        print(f)
# Out:
# .
# .ipynb_checkpoints
# Basic cont.ipynb
# Basic.ipynb
# bike.dat
# bike.dir
# binary
# binary2
# centered
# cities.txt
# eminemsongs.txt
# food.dat
# food.dir
# print_centered
# sample.txt
# ShelfTest.dat
# ShelfTest.dir
# ShelfTest2.dat
# ShelfTest2.dir
# tf.dat
# tf.dir
# timestable.txt
# .\.ipynb_checkpoints
# Basic cont-checkpoint.ipynb
# Basic-checkpoint.ipynb

# %%
# Now lets write a code that will indent the files in a file dir

import os

def list_directories(s):
    
    def dir_list(d):
        nonlocal tab_stop #because we want to avoid shadowing a variable
        files = os.listdir(d)
        for f in files:
            current_dir = os.path.join(d,f)
            if os.path.isdir(current_dir):
                print("\t" * tab_stop + "Directory" + f)
                tab_stop += 1
                dir_list(current_dir)
                tab_stop -= 1
            else:
                print("\t" * tab_stop + f)
    tab_stop = 0
    if os.path.exists(s):
        print("Directory listing of " + s)
        dir_list(s)
    else:
        print(s + " does not exist")
    
list_directories('.')
# Out:
# Directory listing of .
# Directory.ipynb_checkpoints
# 	Basic cont-checkpoint.ipynb
# 	Basic-checkpoint.ipynb
# Basic cont.ipynb
# Basic.ipynb
# bike.dat
# bike.dir
# binary
# binary2
# centered
# cities.txt
# eminemsongs.txt
# food.dat
# food.dir
# print_centered
# sample.txt
# ShelfTest.dat
# ShelfTest.dir
# ShelfTest2.dat
# ShelfTest2.dir
# tf.dat
# tf.dir
# timestable.txt

# %%
# global keyword tells Python to look for a variable in the global scope which is the modules name space but the
# non local keyword tells it to look for that variable in the enclosing scopes

# But you cannot assing a value to the variable that you defined as nonlocal
# the variable has to exist in the outerscope and if you want to assign a value to it,
# you have to do it in the outerscope.

# One thing to remember here is that:
# Only things that create scope in Python are modules functions and classes

# When you define a function Python creates a new name space for it and any variables are part of the local scope

# %%
# Now lets see how nesting works

def spam1():
    
    def spam2():
        
        def spam3():
            z = "even more spam"
            return z
        
        y = "more spam "
        y += spam3()
        return y

    x = "spam "
    x += spam2()
    return x

print(spam1())
# Out:
# spam more spam even more spam

# %%
#now thsi shows how it nestin works, but it would be helpful, if we knew

def spam1():
    
    def spam2():
        
        def spam3():
            z = "even more spam"
            print(f"In spam3, the locals are {locals()}")
            return z
        
        y = "more spam "
        y += spam3()
        print(f"In spam2, the locals are {locals()}")
        return y

    x = "spam "
    x += spam2()
    print(f"In spam1, the locals are {locals()}")
    return x

print(spam1())
# Out:
# In spam3, the locals are {'z': 'even more spam'}
# In spam2, the locals are {'spam3': <function spam1.<locals>.spam2.<locals>.spam3 at 0x000001E071682430>, 'y': 'more spam even more spam'}
# In spam1, the locals are {'spam2': <function spam1.<locals>.spam2 at 0x000001E071682160>, 'x': 'spam more spam even more spam'}
# spam more spam even more spam

# %%
def spam1():
    
    def spam2():
        
        def spam3():
            z = "even "
            z += y     #we can reference y in spam3
            print(f"In spam3, the locals are {locals()}")
            return z
        
        y = "more " + x # we can reference x in spam2
        y += spam3()
        print(f"In spam2, the locals are {locals()}")
        return y

    x = "spam "
    x += spam2()
    print(f"In spam1, the locals are {locals()}")
    return x

print(spam1())
# Out:
# In spam3, the locals are {'z': 'even more spam ', 'y': 'more spam '}
# In spam2, the locals are {'spam3': <function spam1.<locals>.spam2.<locals>.spam3 at 0x000001E071AA4160>, 'y': 'more spam even more spam ', 'x': 'spam '}
# In spam1, the locals are {'spam2': <function spam1.<locals>.spam2 at 0x000001E071AA40D0>, 'x': 'spam more spam even more spam '}
# spam more spam even more spam

# %%
# But lets we optimize the code in line 16 and 17, it will break the code

def spam1():
    
    def spam2():
        
        def spam3():
            z = "even "
            z += y     #we can reference y in spam3
            print(f"In spam3, the locals are {locals()}")
            return z
        
        y = "more " + x # we can reference x in spam2
        y += spam3()
        print(f"In spam2, the locals are {locals()}")
        return y

    x = "spam " + spam2()
    print(f"In spam1, the locals are {locals()}")
    return x

print(spam1())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-87e011f3b90c> in <module>
#      20     return x
#      21
# ---> 22 print(spam1())
#
# <ipython-input-13-87e011f3b90c> in spam1()
#      16         return y
#      17
# ---> 18     x = "spam " + spam2()
#      19     print(f"In spam1, the locals are {locals()}")
#      20     return x
#
# <ipython-input-13-87e011f3b90c> in spam2()
#      11             return z
#      12
# ---> 13         y = "more " + x # we can reference x in spam2
#      14         y += spam3()
#      15         print(f"In spam2, the locals are {locals()}")
#
# NameError: free variable 'x' referenced before assignment in enclosing scope

# %%
# So what actually happened is that spam 2 the function attempts to use the value of 'x'
# but spent spam 2 is called during the initial assignment to 'x' so 'x' doesn't yet have a value
# as a result we get the error free variable 'x'

# %%
# So there are three lesson to learn from this simple change

# Wherever possible try to write functions so that they only use local variables
# and parameters only access global and non-local variables when it's absolutely necessary

# No matter how trivial a change do you think you've made
# test the program thoroughly to make sure you haven't broken anything

# Make sure you include a comment to explain why so the next person who 
# works on your code doesn't do what you've just done

# %%
def spam1():
    
    def spam2():
        
        def spam3():
            z = "even "
            z += y
            print(f"In spam3, the locals are {locals()}")
            return z
        
        y = "more " + x  # y must exist before spam3 is called
        y += spam3()  # do not combine these assignments
        print(f"In spam2, the locals are {locals()}")
        return y

    x = "spam "  # x must exist before spam2 is called
    x += spam2()  #do not combine these assignments
    print(f"In spam1, the locals are {locals()}")
    return x

print(spam1())
# Out:
# In spam3, the locals are {'z': 'even more spam ', 'y': 'more spam '}
# In spam2, the locals are {'spam3': <function spam1.<locals>.spam2.<locals>.spam3 at 0x000001E071AA4430>, 'y': 'more spam even more spam ', 'x': 'spam '}
# In spam1, the locals are {'spam2': <function spam1.<locals>.spam2 at 0x000001E071AA4550>, 'x': 'spam more spam even more spam '}
# spam more spam even more spam

# %%
# A helpful to remember the analogy LEGB

# L: Local
# E: Enclosing (nonlocal or free variables)
# G: Global
# B: Built-in (the names that are builtin Python)
    
# Its the list in order which Python searches for names

# Built-ins are the final place that Python will possible look to when trying to resolve a name
